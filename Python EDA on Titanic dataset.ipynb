# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %%
import matplotlib as plt
# %matplotlib inline

# %%
sk1 = pd.read_csv('E:/Data Science/Skillathon/Exercise/10 Aug/titanic_data - titanic_data.csv')
sk1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sk1.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
sk1.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# ...

# %%
sk1.shape
# Out:
# (891, 12)

# %%
sk1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sk1.iloc[4:25, 4:6]
# Out:
#        Sex   Age
# 4     male  35.0
# 5     male   NaN
# 6     male  54.0
# 7     male   2.0
# 8   female  27.0
# 9   female  14.0
# 10  female   4.0
# 11  female  58.0
# 12    male  20.0
# 13    male  39.0
# 14  female  14.0
# 15  female  55.0
# 16    male   2.0
# 17    male   NaN
# 18  female  31.0
# 19  female   NaN
# 20    male  35.0
# 21    male  34.0
# 22  female  15.0
# 23    male  28.0
# 24  female   8.0

# %%
sk1.loc[4:25,('Name', 'Sex', 'Age', 'Cabin', 'Survived')]
# Out:
#                                                  Name     Sex   Age Cabin  \
# 4                            Allen, Mr. William Henry    male  35.0   NaN
# 5                                    Moran, Mr. James    male   NaN   NaN
# 6                             McCarthy, Mr. Timothy J    male  54.0   E46
# 7                      Palsson, Master. Gosta Leonard    male   2.0   NaN
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0   NaN
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0   NaN
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0    G6
# 11                           Bonnell, Miss. Elizabeth  female  58.0  C103
# 12                     Saundercock, Mr. William Henry    male  20.0   NaN
# 13                        Andersson, Mr. Anders Johan    male  39.0   NaN
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0   NaN
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0   NaN
# ...

# %%
sk1['Age'].plot(kind='bar')

# %%
sk1['Fare'].plot(kind='bar')

# %%
sk1['SibSp'].plot(kind='bar')

# %%
sk1['Fare'].value_counts().plot.bar()

# %%
sk1['SibSp'].value_counts().plot.bar()

# %%
sk1['Parch'].value_counts().plot.bar()

# %%
sk1['SibSp'].plot(kind='hist')

# %%
sk1['SibSp'].plot(kind='pie')

# %%
sk1['SibSp'].value_counts().plot.pie()

# %%
sk1['Parch'].value_counts().plot.pie()

# %%
sk1.plot(kind='box')

# %%
sk1['Age'].plot(kind='pie')

# %%
sk1['Age'].plot(kind='hist')

# %%
sk1.plot(kind='scatter', x= 'Age', y= 'Survived')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sk1.plot(kind='scatter', x= 'Age', y= 'Survived', s = sk1['Fare']*2, figsize = (10,5))
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
sns.distplot(sk1['Parch'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py in kdensityfft(X, kernel, bw, weights, gridsize, adjust, clip, cut, retgrid)
#     450     try:
# --> 451         bw = float(bw)
#     452     except:
#
# ValueError: could not convert string to float: 'scott'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-48-34203ccc413e> in <module>
# ----> 1 sns.distplot(sk1['Parch'])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     231     if kde:
#     232         kde_color = kde_kws.pop("color", color)
# ...

# %%
sns.distplot(sk1['Age'])

# %%
sns.distplot(sk1['Age'], color = 'y')

# %%
sk1['Sex'].value_counts().plot.pie()

# %%
sk1['Embarked'].value_counts().plot.pie()

# %%
sns.distplot(sk1['Survived'], color = 'g')

# %%
sns.distplot(sk1['Fare'], kde=False, vertical=True, color ='r')

# %%
sns.barplot(x='Sex', y= 'Fare', data= sk1)

# %%
sns.barplot(x='Embarked', y= 'Age', hue = 'Sex', data= sk1)

# %%
sns.countplot(x='Sex', data=sk1)

# %%
sns.countplot(x='Embarked', data=sk1)

# %%
sns.countplot(x='Sex', hue= 'Embarked', data=sk1)

# %%
sns.heatmap(sk1.corr())

# %%
sns.pairplot(sk1)

# %%
sns.jointplot(x=sk1['Age'], y=sk1['Fare'], kind="hex")

# %%
sns.lmplot(x='Age', y='Fare', col = 'Sex', data = sk1)

# %%
sns.lmplot(x='Age', y='Fare', hue = 'Sex', data = sk1)

# %%
sns.lmplot(x='Age', y='Fare', hue = 'Embarked', data = sk1)

# %%
sns.lmplot(x='Age', y='Fare', hue = 'Sex', data = sk1, markers=['o','x'])

# %%
np_array = sk1.to_numpy()
np_array
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
sk1['SibSp'].value_counts().plot.pie()

# %%
sk1['SibSp'].value_counts().plot.bar()

# %%
sk1['SibSp'].value_counts().plot.box()

# %%
sk1['SibSp'].value_counts().plot.line()

# %%
sk1['SibSp'].value_counts().plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-13b492db8c3e> in <module>
# ----> 1 sk1['SibSp'].value_counts().plot.scatter()
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'
